# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Name: Satyadev Tummala <br>
# Empid : 2000076426

# %%
df = pd.read_csv('cars.csv')

# %%
df.head(5)
# Out:
#    symboling normalized losses         make fuel-type aspiration num of doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body style drive wheels engine location  wheel base  ...  engine size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num of doors       205 non-null    object
#  6   body style         205 non-null    object
#  7   drive wheels       205 non-null    object
#  8   engine location    205 non-null    object
#  9   wheel base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb weight        205 non-null    int64
#  14  engine type        205 non-null    object
#  15  num of cylinders   205 non-null    object
# ...

# %%
cols = df.columns

# %%
for col in cols:
    print(col,df[col].unique())
# Out:
# symboling [ 3  1  2  0 -1 -2]
# normalized losses ['?' '164' '158' '192' '188' '121' '98' '81' '118' '148' '110' '145' '137'
#  '101' '78' '106' '85' '107' '104' '113' '150' '129' '115' '93' '142'
#  '161' '153' '125' '128' '122' '103' '168' '108' '194' '231' '119' '154'
#  '74' '186' '83' '102' '89' '87' '77' '91' '134' '65' '197' '90' '94'
#  '256' '95']
# make ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'mazda' 'mercedes-benz' 'mercury' 'mitsubishi' 'nissan' 'peugot'
#  'plymouth' 'porsche' 'renault' 'saab' 'subaru' 'toyota' 'volkswagen'
#  'volvo']
# fuel-type ['gas' 'diesel']
# aspiration ['std' 'turbo']
# num of doors ['two' 'four' '?']
# body style ['convertible' 'hatchback' 'sedan' 'wagon' 'hardtop']
# drive wheels ['rwd' 'fwd' '4wd']
# engine location ['front' 'rear']
# wheel base [ 88.6  94.5  99.8  99.4 105.8  99.5 101.2 103.5 110.   88.4  93.7 103.3
#   95.9  86.6  96.5  94.3  96.  113.  102.   93.1  95.3  98.8 104.9 106.7
# ...

# %%
for col in cols:
    if df[col].isna().any():
        print(col)
# Out:
# bore
# stroke
# horsepower

# %%
# Out:
#     symboling normalized losses   make fuel-type aspiration num of doors  \
# 55          3               150  mazda       gas        std          two
# 56          3               150  mazda       gas        std          two
# 57          3               150  mazda       gas        std          two
# 58          3               150  mazda       gas        std          two
#
#    body style drive wheels engine location  wheel base  ...  engine size  \
# 55  hatchback          rwd           front        95.3  ...           70
# 56  hatchback          rwd           front        95.3  ...           70
# 57  hatchback          rwd           front        95.3  ...           70
# 58  hatchback          rwd           front        95.3  ...           80
#
#     fuel system  bore  stroke compression ratio horsepower  peak rpm city mpg  \
# 55         4bbl   NaN     NaN               9.4        101      6000       17
# ...

# %%
# columns containing '?' : normalized losses,num of doors,peak rpm,price

# now replacing those values

# %%
df.replace({"?":np.nan},inplace=True)

# %%
for col in df.columns:
    df[col].fillna(df[col].mode().iloc[0],inplace=True)

# %%
# Check for missing values
for col in cols:
    if df[col].isna().any():
        print(col)

# %%
# clean dataset

# %%
df
# Out:
#      symboling normalized losses         make fuel-type aspiration  \
# 0            3               161  alfa-romero       gas        std
# 1            3               161  alfa-romero       gas        std
# 2            1               161  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num of doors   body style drive wheels engine location  wheel base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %% [markdown]
# # questions
# 1)What percentage of cars will be suitable for a family (i.e. num of doors=4, price <20,000 & mileage >17)? <br>
# 2)Which company has generated more car options for customers?<br>
# 3)What is the ratio of diesel cars to that gas ones?<br>
# 4)What is the count of performance cars present in the dataset (horsepower > 150)?<br>
# 5)Which is the most compact among all cars?<br>
# 6)What are the main factors that are associated with the mileage of a car?<br>
# 7)What percentage of cars are budget-friendly (price < 10,00)?<br>
# 8)Which cars are the most efficient of all (city mpg >= 30)?<br>
# 9)What percentage of data is missing from the dataset?<br>
# 10)Which feature of the car affects the most to the pricing?<br>

# %%
#q1

# %%
df['price'] = df['price'].astype('int64')

# %%
numFamilyCars = df[(df['num of doors'] == 'four') & (df['price'] < 20000) & (df['city mpg'] > 17)].count().iloc[0]

# %%
totalCars = df.count().iloc[0]
percentage = numFamilyCars / totalCars
print('total cars',totalCars)
# Out:
# total cars 205

# %%
percentage * 100
# Out:
# 47.3170731707317

# %%
#q2

# %%
df.groupby('make')['make'].count().sort_values(ascending=False).idxmax()
# Out:
# 'toyota'

# %%
#q3

# %%
df['fuel-type'].unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
countGas  = int(df[df['fuel-type'] == 'gas'].count().iloc[0])
countDisel = int(df[df['fuel-type'] == 'diesel'].count().iloc[0])
print("number of gas cars:",countGas)
print("number of disel cars:",countDisel)
totalCars = df.count().iloc[0]
ratio = countDisel/countGas

print("the ratio of disel w.r.t to gas:",str(ratio))
# Out:
# number of gas cars: 185
# number of disel cars: 20
# the ratio of disel w.r.t to gas: 0.10810810810810811

# %%
# q4

# %%
df['horsepower'].fillna(df['horsepower'].mode().iloc[0],inplace=True)

# %%
df['horsepower']  = df['horsepower'].astype('int64')

# %%
df[df['horsepower'] > 150].count().iloc[0]
# Out:
# 32

# %%
# q5

# %%
df[df['body style'] == 'hatchback'].sort_values('curb weight').iloc[0]
# Out:
# symboling                    2
# normalized losses          121
# make                 chevrolet
# fuel-type                  gas
# aspiration                 std
# num of doors               two
# body style           hatchback
# drive wheels               fwd
# engine location          front
# wheel base                88.4
# length                   141.1
# width                     60.3
# height                    53.2
# curb weight               1488
# engine type                  l
# num of cylinders         three
# engine size                 61
# fuel system               2bbl
# bore                      2.91
# stroke                    3.03
# compression ratio          9.5
# horsepower                  48
# peak rpm                  5100
# city mpg                    47
# highway mpg                 53
# price                     5151
# Name: 18, dtype: object

# %%
#q6

# %%
df.corr()[['city mpg','highway mpg']]
# Out:
#                    city mpg  highway mpg
# symboling         -0.035823     0.034606
# wheel base        -0.470414    -0.544082
# length            -0.670909    -0.704662
# width             -0.642704    -0.677218
# height            -0.048640    -0.107358
# curb weight       -0.757414    -0.797465
# engine size       -0.653658    -0.677470
# compression ratio  0.324701     0.265201
# horsepower        -0.796862    -0.768096
# city mpg           1.000000     0.971337
# highway mpg        0.971337     1.000000
# price             -0.667215    -0.690173

# %% [markdown]
# <B>from the above table we can figure out the main factors that affect the mileage of the car are:
# length, width, curb weight, engine size, horsepower, highway mpg, price
# the corr is either positive or negative for these features and above 0.5</B>

# %%
#q7

# %%
bugetCars = df[df['price'] < 10000].count().iloc[0]
percentageCars = (bugetCars / totalCars) * 100
print("Percentage of cars that are budger friendly",percentageCars)
# Out:
# Percentage of cars that are budger friendly 47.80487804878049

# %%
#q8

# %%
df[df['city mpg'] >= 30].sort_values(by='city mpg',ascending = False)
# Out:
#      symboling normalized losses        make fuel-type aspiration  \
# 30           2               137       honda       gas        std
# 18           2               121   chevrolet       gas        std
# 90           1               128      nissan    diesel        std
# 20           0                81   chevrolet       gas        std
# 160          0                91      toyota       gas        std
# 32           1               101       honda       gas        std
# 159          0                91      toyota    diesel        std
# 44           1               161       isuzu       gas        std
# 45           0               161       isuzu       gas        std
# 19           1                98   chevrolet       gas        std
# 21           1               118       dodge       gas        std
# 187          2                94  volkswagen    diesel      turbo
# 184          2                94  volkswagen    diesel        std
# ...

# %%
#q9

# %%
df[df.isna()].count()
# zero missing records so percentage of missing data is 0, since we filled '?' previously the data now is cleaned
# Out:
# symboling            0
# normalized losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num of doors         0
# body style           0
# drive wheels         0
# engine location      0
# wheel base           0
# length               0
# width                0
# height               0
# curb weight          0
# engine type          0
# num of cylinders     0
# engine size          0
# fuel system          0
# bore                 0
# stroke               0
# compression ratio    0
# horsepower           0
# peak rpm             0
# city mpg             0
# highway mpg          0
# price                0
# dtype: int64

# %%
# q10

# %%
df.corr()['price']
# Out:
# symboling           -0.082396
# wheel base           0.582915
# length               0.682528
# width                0.729009
# height               0.133761
# curb weight          0.820807
# engine size          0.861769
# compression ratio    0.070789
# horsepower           0.759731
# city mpg            -0.667215
# highway mpg         -0.690173
# price                1.000000
# Name: price, dtype: float64

# %% [markdown]
# <b>The feature that affects the car price most is the enginge_size since it has the highest correleation </b>
