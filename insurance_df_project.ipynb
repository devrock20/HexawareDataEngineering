# %%
import pandas as pd
import seaborn as sns
sns.set_theme(style="whitegrid")
df = pd.read_csv('insurance.csv')

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.corr()
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
bx = sns.boxplot(x=df['charges'])

# %%
sns.swarmplot(x="region", y="charges", data=df)
# Out:
# /opt/homebrew/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 43.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/homebrew/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 37.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/homebrew/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 39.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/homebrew/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 37.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='region', ylabel='charges'>

# %%
sns.swarmplot(x="smoker", y="charges", data=df)
# Out:
# /opt/homebrew/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 67.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='smoker', ylabel='charges'>

# %%
sns.swarmplot(x="sex", y="charges", data=df)
# Out:
# /opt/homebrew/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 40.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/homebrew/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 35.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='sex', ylabel='charges'>

# %%
sns.swarmplot(x="bmi", y="charges", data=df)
# Out:
# /opt/homebrew/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/homebrew/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/homebrew/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 66.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/homebrew/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 25.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.relplot(x="charges", y="age", data=df,hue='smoker');

# %%
sns.relplot(x="charges", y="age", data=df,hue='smoker',col="sex");

# %%
sns.relplot(x="charges", y="age", data=df,hue='smoker',col="region");

# %%
sns.relplot(x="charges", y="age", data=df,hue='smoker',col="region",style="children");

# %%
sns.relplot(x="charges", y="children", data=df,hue="smoker");

# %%
sns.relplot(x="charges", y="children", data=df,hue="smoker",col="region");

# %%
new_df = df.groupby(['age','sex','region'])['charges'].sum().reset_index()

# %%
new_df
# Out:
#      age     sex     region        charges
# 0     18  female  northeast   72969.166819
# 1     18  female  southeast  142265.344500
# 2     18    male  northeast  168910.273090
# 3     18    male  southeast  104804.226980
# 4     19  female  northwest  174687.030080
# ..   ...     ...        ...            ...
# 365   64  female  southwest  109538.116000
# 366   64    male  northeast   28805.490000
# 367   64    male  northwest   44377.154120
# 368   64    male  southeast  151642.833600
# 369   64    male  southwest   28811.235000
#
# [370 rows x 4 columns]

# %%
new_df.corr()
# Out:
#               age   charges
# age      1.000000  0.204731
# charges  0.204731  1.000000

# %%
ax = sns.boxplot(x=new_df["charges"])

# %%
bx = sns.boxplot(x=df['age'])

# %%
sns.boxplot(x=df['children'])
# Out:
# <AxesSubplot:xlabel='children'>

# %%
sns.pairplot(df,hue="smoker")
