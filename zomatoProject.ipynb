# %% [markdown]
# # Zomato Project

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Name: Satyadev Tummala

# %%
zomato_df = pd.read_csv('Data package from July 8th./zomato.csv',encoding="ISO-8859-1")

# %%
country_codes = pd.read_excel('Data package from July 8th./Country-Code.xlsx')

# %%
country_codes
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
zomato_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'cc', 'City', 'Address', 'Locality',
#        'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %% [raw]
# Question1)
# Which restaurant has the largest number of votes from the customer

# %%
zomato_df[zomato_df['Votes'] == zomato_df['Votes'].max()]
# Out:
#      Restaurant ID Restaurant Name  cc       City  \
# 728          51705            Toit   1  Bangalore
#
#                                                Address     Locality  \
# 728  298, Namma Metro Pillar 62, 100 Feet Road, Ind...  Indiranagar
#
#            Locality Verbose  Longitude   Latitude                  Cuisines  \
# 728  Indiranagar, Bangalore  77.640709  12.979166  Italian, American, Pizza
#
#      ...            Currency Has Table booking Has Online delivery  \
# 728  ...  Indian Rupees(Rs.)                No                  No
#
#     Is delivering now Switch to order menu Price range  Aggregate rating  \
# 728                No                   No           4               4.8
#
#      Rating color Rating text  Votes
# 728    Dark Green   Excellent  10934
#
# [1 rows x 21 columns]

# %%
merged_df  = zomato_df.merge(country_codes,left_on="cc",right_on="Country Code",how="inner")

# %%
merged_df
# Out:
#       Restaurant ID           Restaurant Name   cc              City  \
# 0           6317637          Le Petit Souffle  162       Makati City
# 1           6304287          Izakaya Kikufuji  162       Makati City
# 2           6300002    Heat - Edsa Shangri-La  162  Mandaluyong City
# 3           6318506                      Ooma  162  Mandaluyong City
# 4           6314302               Sambo Kojin  162  Mandaluyong City
# ...             ...                       ...  ...               ...
# 9546        5915730              NamlÛ± Gurme  208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±  208         ÛÁstanbul
# 9548        5915807                     Huqqa  208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve  208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery  208         ÛÁstanbul
#
#                                                 Address  \
# 0     Third Floor, Century City Mall, Kalayaan Avenu...
# ...

# %% [raw]
# Question2)
# 2) Which city has more number of poor and not rated rating than very good rating in each country?

# %%
pd.crosstab(merged_df['City'],merged_df['Rating text'])
# Out:
# Rating text      Average  Excellent  Good  Not rated  Poor  Very Good
# City
# Abu Dhabi              0          7     1          0     0         12
# Agra                   1          1     9          0     0          9
# Ahmedabad              0          3     5          0     0         13
# Albany                 7          0    13          0     0          0
# Allahabad             15          0     5          0     0          0
# ...                  ...        ...   ...        ...   ...        ...
# Weirton                0          0     1          0     0          0
# Wellington City        0          3     1          0     0         16
# Winchester Bay         1          0     0          0     0          0
# Yorkton                1          0     0          0     0          0
# ÛÁstanbul              0          5     2          0     0          7
#
# [141 rows x 6 columns]

# %% [raw]
# Question3)
# 3) Which city is costliest in each country? ( Assume all the currency are of same value)

# %%
groups = merged_df.groupby(merged_df['Country'])

# %%
for name,df in groups:
    print(name)
    print(df[df['Average Cost for two'] == df['Average Cost for two'].max()]['City'])
# Out:
# Australia
# 534    Paynesville
# Name: City, dtype: object
# Brazil
# 76    Sí£o Paulo
# Name: City, dtype: object
# Canada
# 542    Vineland Station
# Name: City, dtype: object
# India
# 7543    New Delhi
# Name: City, dtype: object
# Indonesia
# 9283    Jakarta
# 9284    Jakarta
# Name: City, dtype: object
# New Zealand
# 9329    Wellington City
# Name: City, dtype: object
# Phillipines
# 8    Pasay City
# Name: City, dtype: object
# Qatar
# 9433    Doha
# Name: City, dtype: object
# Singapore
# 546    Singapore
# Name: City, dtype: object
# South Africa
# 9484    Pretoria
# Name: City, dtype: object
# Sri Lanka
# 9512    Colombo
# Name: City, dtype: object
# Turkey
# 9526    Ankara
# Name: City, dtype: object
# UAE
# 581    Abu Dhabi
# 590        Dubai
# 597        Dubai
# Name: City, dtype: object
# United Kingdom
# 9384    London
# Name: City, dtype: object
# United States
# 336    Orlando
# Name: City, dtype: object

# %% [raw]
# Question4)
# In india how many restaurants are present in each locality?

# %%
country_groups = merged_df.groupby('Country')
india_df = country_groups.get_group('India')
india_df.groupby('Locality')['Restaurant ID'].count()
# Out:
# Locality
#  ILD Trade Centre Mall, Sohna Road      2
# 12th Square Building, Banjara Hills     1
# A Hotel, Gurdev Nagar                   1
# ARSS Mall, Paschim Vihar                1
# Aaya Nagar                              1
#                                        ..
# Yusuf Sarai                            25
# Z Square Mall, Mall Road                1
# Zakir Nagar                            14
# Zoo Tiniali                             4
# ibis New Delhi, Aerocity                2
# Name: Restaurant ID, Length: 784, dtype: int64

# %% [raw]
# Question5)
# Which city has the most number of restaurants in each country?

# %%
new_df = merged_df.groupby(['City',"Country"])['Restaurant ID'].count().sort_values(ascending=False).reset_index()

# %%
new_df.rename(columns={"Restaurant ID": "Count"},inplace=True)
new_df.drop_duplicates('Country')
# Out:
#                 City         Country  Count
# 0          New Delhi           India   5473
# 16        Manchester  United Kingdom     20
# 18             Macon   United States     20
# 26         Abu Dhabi             UAE     20
# 29   Wellington City     New Zealand     20
# 36        Sí£o Paulo          Brazil     20
# 39         Singapore       Singapore     20
# 47          Pretoria    South Africa     20
# 52           Colombo       Sri Lanka     20
# 60              Doha           Qatar     20
# 73            Ankara          Turkey     20
# 79           Jakarta       Indonesia     16
# 83       Taguig City     Phillipines      4
# 91   Hepburn Springs       Australia      2
# 102          Yorkton          Canada      1

# %% [raw]
# Question6)
# 6) Which franchise has the highest number of Restaurants?

# %%
merged_df.groupby(['Restaurant Name'])['Restaurant ID'].count().sort_values(ascending=False).reset_index().iloc[0]
# Out:
# Restaurant Name    Cafe Coffee Day
# Restaurant ID                   83
# Name: 0, dtype: object

# %%
len(merged_df)
# Out:
# 9551

# %% [raw]
# Question7
# 7) How many Restaurants are accepting online orders?

# %%
merged_df[merged_df['Has Online delivery'] == 'Yes']['Restaurant ID'].count()
# Out:
# 2451

# %% [raw]
# Question8
# 8) How many have a book table facility?

# %%
merged_df[merged_df['Has Table booking'] == 'Yes']['Restaurant ID'].count()
# Out:
# 1158

# %% [raw]
# Question9
# 9) Which location has the highest number of Restaurants?

# %%
merged_df.groupby('City')['Restaurant ID'].count().sort_values(ascending=False).reset_index().iloc[0]
# Out:
# City             New Delhi
# Restaurant ID         5473
# Name: 0, dtype: object

# %% [raw]
# Question 10)
# 10) How many types of Restaurant types are there?

# %%
new_arr= []
for cusine in merged_df['Cuisines'].unique():
    try:
        new_arr.extend(cusine.split(','))
    except :
        continue
len(set(new_arr))
# Out:
# 249

# %%
# Out:
# 249

# %% [raw]
# Question 11
# 11) What is the most liked Restaurant type?

# %%
merged_df[merged_df['Votes']== merged_df['Votes'].max()]['Cuisines']
# Out:
# 728    Italian, American, Pizza
# Name: Cuisines, dtype: object

# %% [raw]
# Question 12
# 12) What is the Average cost for 2 persons?

# %%
merged_df.groupby('City')['Average Cost for two'].mean()
# Out:
# City
# Abu Dhabi           182.000000
# Agra               1065.000000
# Ahmedabad           857.142857
# Albany               19.750000
# Allahabad           517.500000
#                       ...
# Weirton              25.000000
# Wellington City      71.250000
# Winchester Bay       25.000000
# Yorkton              25.000000
# ÛÁstanbul            81.428571
# Name: Average Cost for two, Length: 141, dtype: float64

# %% [raw]
# 13) What is the most liked Dish type?
