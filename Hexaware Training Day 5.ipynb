# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Bank_churn_modelling - Copy.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df[['CreditScore','Age']].describe()
# Out:
#         CreditScore           Age
# count  10000.000000  10000.000000
# mean     650.528800     38.921800
# std       96.653299     10.487806
# min      350.000000     18.000000
# 25%      584.000000     32.000000
# 50%      652.000000     37.000000
# 75%      718.000000     44.000000
# max      850.000000     92.000000

# %%
insurance_df = pd.read_csv('insurance.csv')

# %%
insurance_df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
insurance_df[['age','bmi']].corr()
# Out:
#           age       bmi
# age  1.000000  0.109272
# bmi  0.109272  1.000000

# %%
insurance_df[['age','bmi']].cov()
# Out:
#             age        bmi
# age  197.401387   9.362337
# bmi    9.362337  37.187884

# %%
insurance_df['charges'].quantile(0.75)
# Out:
# 16639.912515

# %%
insurance_df['charges'].quantile(0.90)
# Out:
# 34831.7197

# %%
insurance_df['charges'].quantile(0.25)
# Out:
# 4740.28715

# %%
insurance_df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
insurance_df.query('age<20 and smoker!="yes"')
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1      18    male  33.770         1     no  southeast   1725.55230
# 15     19    male  24.600         1     no  southwest   1837.23700
# 22     18    male  34.100         0     no  southeast   1137.01100
# 31     18  female  26.315         0     no  northeast   2198.18985
# 32     19  female  28.600         5     no  southwest   4687.79700
# ...   ...     ...     ...       ...    ...        ...          ...
# 1315   18    male  28.310         1     no  northeast  11272.33139
# 1316   19  female  20.600         0     no  southwest   1731.67700
# 1317   18    male  53.130         0     no  southeast   1163.46270
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
#
# [107 rows x 7 columns]

# %%
insurance_df['charges'] = insurance_df['charges'].apply(lambda x : x + 100)

# %%
insurance_df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16984.92400
# 1      18    male  33.770         1     no  southeast   1825.55230
# 2      28    male  33.000         3     no  southeast   4549.46200
# 3      33    male  22.705         0     no  northwest  22084.47061
# 4      32    male  28.880         0     no  northwest   3966.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10700.54830
# 1334   18  female  31.920         0     no  northeast   2305.98080
# 1335   18  female  36.850         0     no  southeast   1729.83350
# 1336   21  female  25.800         0     no  southwest   2107.94500
# 1337   61  female  29.070         0    yes  northwest  29241.36030
#
# [1338 rows x 7 columns]

# %%
out = pd.crosstab(df['Geography'],df['Exited'],margins=True)

# %%
print(out)
# Out:
# Exited        0     1    All
# Geography
# France     4204   810   5014
# Germany    1695   814   2509
# Spain      2064   413   2477
# All        7963  2037  10000

# %%
out[1]/out['All']
# Out:
# Geography
# France     0.161548
# Germany    0.324432
# Spain      0.166734
# All        0.203700
# dtype: float64

# %%
pd.crosstab(df['Geography'],[df['Gender'],df['Exited']],margins=True)
# Out:
# Gender    Female        Male         All
# Exited         0     1     0    1
# Geography
# France      1801   460  2403  350   5014
# Germany      745   448   950  366   2509
# Spain        858   231  1206  182   2477
# All         3404  1139  4559  898  10000

# %%
import numpy as np
pd.crosstab(df['Geography'],df['Gender'],values=df['Age'],aggfunc=np.average)
# Out:
# Gender        Female       Male
# Geography
# France     38.773994  38.296404
# Germany    40.154233  39.424772
# Spain      39.199265  38.649135

# %%
g = df.groupby('Geography')

# %%
print(g)

# %%
for name,datframe in g:
    print(name)
    print(datframe)
# Out:
# France
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 6             7    15592531   Bartlett          822    France    Male   50
# 8             9    15792365         He          501    France    Male   44
# ...         ...         ...        ...          ...       ...     ...  ...
# 9994       9995    15719294       Wood          800    France  Female   29
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9999      10000    15628319     Walker          792    France  Female   28
#
# ...

# %%
france = g.get_group('France')
germany = g.get_group('Germany')
spain = g.get_group('Spain')

# %%
france.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 6          7    15592531  Bartlett          822    France    Male   50
# 8          9    15792365        He          501    France    Male   44
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 6       7       0.00              2          1               1
# 8       4  142051.07              2          0               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 2        113931.57       1
# 3         93826.63       0
# 6         10062.80       0
# ...

# %%
germany.head()
# Out:
#     RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 7           8    15656148      Obinna          376   Germany  Female   29
# 15         16    15643966     Goforth          616   Germany    Male   45
# 16         17    15737452       Romeo          653   Germany    Male   58
# 26         27    15736816       Young          756   Germany    Male   36
# 28         29    15728693  McWilliams          574   Germany  Female   43
#
#     Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 7        4  115046.74              4          1               0
# 15       3  143129.41              2          0               1
# 16       1  132602.88              1          1               0
# 26       2  136815.64              1          1               1
# 28       3  141349.43              1          1               1
#
#     EstimatedSalary  Exited
# 7         119346.88       1
# 15         64327.26       0
# 16          5097.67       1
# ...

# %%
g.max()
# Out:
#            RowNumber  CustomerId Surname  CreditScore Gender  Age  Tenure  \
# Geography
# France         10000    15815660    Zuev          850   Male   92      10
# Germany         9999    15815656  Zuyeva          850   Male   84      10
# Spain           9993    15815690  Zuyeva          850   Male   88      10
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# Geography
# France     238387.56              4          1               1
# Germany    214346.96              4          1               1
# Spain      250898.09              4          1               1
#
#            EstimatedSalary  Exited
# Geography
# France           199929.17       1
# Germany          199970.74       1
# Spain            199992.48       1

# %%
g.count()
# Out:
#            RowNumber  CustomerId  Surname  CreditScore  Gender   Age  Tenure  \
# Geography
# France          5014        5014     5014         5014    5014  5014    5014
# Germany         2509        2509     2509         2509    2509  2509    2509
# Spain           2477        2477     2477         2477    2477  2477    2477
#
#            Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# Geography
# France        5014           5014       5014            5014             5014
# Germany       2509           2509       2509            2509             2509
# Spain         2477           2477       2477            2477             2477
#
#            Exited
# Geography
# France       5014
# Germany      2509
# Spain        2477

# %%
g.describe()
# Out:
#           RowNumber                                                           \
#               count         mean          std  min      25%     50%      75%
# Geography
# France       5014.0  5025.228560  2873.666719  1.0  2585.25  5003.5  7495.75
# Germany      2509.0  5000.278996  2918.980192  8.0  2461.00  4997.0  7583.00
# Spain        2477.0  4950.667743  2881.454458  2.0  2356.00  5000.0  7435.00
#
#                    CustomerId                ... EstimatedSalary             \
#                max      count          mean  ...             75%        max
# Geography                                    ...
# France     10000.0     5014.0  1.569065e+07  ...       149295.36  199929.17
# Germany     9999.0     2509.0  1.569056e+07  ...       151083.80  199970.74
# Spain       9993.0     2477.0  1.569192e+07  ...       147278.43  199992.48
#
#            Exited
#             count      mean       std  min  25%  50%  75%  max
# Geography
# ...

# %%
pd.set_option('display.max_rows',500)
pd.set_option('display.max_column',500)

# %%
g.describe()
# Out:
#           RowNumber                                                           \
#               count         mean          std  min      25%     50%      75%
# Geography
# France       5014.0  5025.228560  2873.666719  1.0  2585.25  5003.5  7495.75
# Germany      2509.0  5000.278996  2918.980192  8.0  2461.00  4997.0  7583.00
# Spain        2477.0  4950.667743  2881.454458  2.0  2356.00  5000.0  7435.00
#
#                    CustomerId                                          \
#                max      count          mean           std         min
# Geography
# France     10000.0     5014.0  1.569065e+07  71375.837573  15565714.0
# Germany     9999.0     2509.0  1.569056e+07  73228.429284  15565779.0
# Spain       9993.0     2477.0  1.569192e+07  71765.540066  15565701.0
#
#                                                             CreditScore  \
#                    25%         50%          75%         max       count
# Geography
# ...

# %%
insurance_df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16984.92400
# 1      18    male  33.770         1     no  southeast   1825.55230
# 2      28    male  33.000         3     no  southeast   4549.46200
# 3      33    male  22.705         0     no  northwest  22084.47061
# 4      32    male  28.880         0     no  northwest   3966.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10700.54830
# 1334   18  female  31.920         0     no  northeast   2305.98080
# 1335   18  female  36.850         0     no  southeast   1729.83350
# 1336   21  female  25.800         0     no  southwest   2107.94500
# 1337   61  female  29.070         0    yes  northwest  29241.36030
#
# [1338 rows x 7 columns]

# %%
new_group = insurance_df.groupby('region')

# %%
for name,datframe in new_group:
    print(name)
# Out:
# northeast
# northwest
# southeast
# southwest

# %%
northeast = new_group.get_group('northeast')
northwest = new_group.get_group('northwest')
southeast = new_group.get_group('southeast')
southwest = new_group.get_group('southwest')

# %%
northeast.head(5)
# Out:
#     age     sex     bmi  children smoker     region      charges
# 8    37    male  29.830         2     no  northeast   6506.41070
# 10   25    male  26.220         0     no  northeast   2821.32080
# 16   52  female  30.780         1     no  northeast  10897.33620
# 17   23    male  23.845         0     no  northeast   2495.17155
# 20   60  female  36.005         0     no  northeast  13328.84695

# %%
northeast.describe()
# Out:
#               age         bmi    children       charges
# count  324.000000  324.000000  324.000000    324.000000
# mean    39.268519   29.173503    1.046296  13506.384516
# std     14.069007    5.937513    1.198949  11255.803066
# min     18.000000   15.960000    0.000000   1794.796400
# 25%     27.000000   24.866250    0.000000   5294.322288
# 50%     39.500000   28.880000    1.000000  10157.652025
# 75%     51.000000   32.893750    2.000000  16787.364100
# max     64.000000   48.070000    5.000000  58671.074480

# %%
new_group.get_group()

# %%
insurance.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [65], in <cell line: 1>()
# ----> 1 insurance.dtypes
#
# NameError: name 'insurance' is not defined

# %%
df = pd.read_csv('Bank_churn_modelling - Copy.csv')

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                 object
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df[~df['Age'].str.isnumeric()]
# Out:
#     RowNumber  CustomerId Surname  CreditScore Geography Gender  Age  Tenure  \
# 40         41    15619360   Hsiao          472     Spain   Male  Sam       4
#
#     Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 40      0.0              1          1               0         70154.22       0

# %%
# Out:
# /var/folders/qv/v11rk_vn2w752ccf09rpdt1r0000gn/T/ipykernel_1632/885997168.py:1: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   df = pd.concat(df,insurance_df)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [77], in <cell line: 1>()
# ----> 1 df = pd.concat(df,insurance_df)
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
insurance_df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16984.92400
# 1      18    male  33.770         1     no  southeast   1825.55230
# 2      28    male  33.000         3     no  southeast   4549.46200
# 3      33    male  22.705         0     no  northwest  22084.47061
# 4      32    male  28.880         0     no  northwest   3966.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10700.54830
# 1334   18  female  31.920         0     no  northeast   2305.98080
# 1335   18  female  36.850         0     no  southeast   1729.83350
# 1336   21  female  25.800         0     no  southwest   2107.94500
# 1337   61  female  29.070         0    yes  northwest  29241.36030
#
# [1338 rows x 7 columns]

# %%
df2 = pd.DataFrame({"age":[20,21,18,20],"sex":["Male","Female","Male","Female"],
                    "children":[0,1,2,3],"smoker":["yes","no","yes","no"],
                    "region":["southwest","northwest","northeast","southeast"],
                    "charges":[16984.92400,22084.47061,2305.98080,2107.94500]
                   })

# %%
flatfile = pd.concat([insurance_df,df2],axis=0,ignore_index=True)

# %%
flatfile.shape
# Out:
# (1342, 7)

# %%
idd =list(range(1,1344))

# %%
df3 = pd.DataFrame({"ID":idd})

# %%
df3.shape
# Out:
# (1343, 1)

# %%
df3
# Out:
#         ID
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# ...    ...
# 1338  1339
# 1339  1340
# 1340  1341
# 1341  1342
# 1342  1343
#
# [1343 rows x 1 columns]

# %%
zomato = pd.read_csv("zomato.csv", encoding = "ISO-8859-1")

# %%
zomato.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'cc', 'City', 'Address', 'Locality',
#        'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
country_df = pd.read_csv("CountryCode.csv")

# %%
country_df
# Out:
#      cc         Country
# 0     1           India
# 1    14       Australia
# 2    30          Brazil
# 3    37          Canada
# 4    94       Indonesia
# 5   148     New Zealand
# 6   162     Phillipines
# 7   166           Qatar
# 8   184       Singapore
# 9   189    South Africa
# 10  191       Sri Lanka
# 11  208          Turkey
# 12  214             UAE
# 13  215  United Kingdom
# 14  216   United States

# %%
merged_df = pd.merge(zomato,country_df,on="cc",how="inner")

# %%
data1 =  {"age":[20,21,18,20],
      "sex":["Male","Female","Male","Female"],
      "bmi":[23.25,35.25,56.25,33.25],
    "children":[0,1,2,3],
      "smoker":["yes","no","yes","no"],
    "region":["southwest","northwest","northeast","southeast"],
    "charges":[16984.92400,22084.47061,2305.98080,2107.94500],
      "ID":[2,6,4,5]
    }
data1 = pd.DataFrame(data1)

# %%
data2 = {
    "BP":["HIGH","HIGH","LOW","LOW"],
    "ID":[2,6,1,4]
}
data2 = pd.DataFrame(data2)

# %%
merged = pd.merge(data1,data2,on="ID",how="right")

# %%
b = insurance_df['charges']
b.head()
# Out:
# 0    16984.92400
# 1     1825.55230
# 2     4549.46200
# 3    22084.47061
# 4     3966.85520
# Name: charges, dtype: float64

# %%
insurance_df.drop('charges',axis=1,inplace=True)

# %%
insurance_df.insert(3,'Charges',b)

# %%
insurance_df.head()
# Out:
#    age     sex     bmi      Charges  children smoker     region
# 0   19  female  27.900  16984.92400         0    yes  southwest
# 1   18    male  33.770   1825.55230         1     no  southeast
# 2   28    male  33.000   4549.46200         3     no  southeast
# 3   33    male  22.705  22084.47061         0     no  northwest
# 4   32    male  28.880   3966.85520         0     no  northwest
